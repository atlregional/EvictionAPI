# %%
import os
import json
import utils.dataReader as dataReader
import utils.geocoder as geocoder
import utils.aggregater as aggregater
import utils.insertCsvToDB as insertCsvToDB
import checkCurrentDatabaseByMonthly as checkDatabase
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import requests

# %%
def test():
    with open('./config.json') as configFile:
        config = json.load(configFile)
    #define global variables
    filePathForRawCaseData = config['filePathForRawCaseData']
    filePathForPreRawCaseData = config['filePathForPreRawCaseData']
    filePathForBackUpFolderOneLevelUp = config['filePathForBackUpFolderOneLevelUp']
    counties = config['counties']
    filePathForWorkFolder = config['filePathForWorkFolder']
    filePathForWorkFolderRawData = config['filePathForWorkFolderRawData']
    filePathForWorkFolderPreRawData = config['filePathForWorkFolderPreRawData']


    fileNamePool,countyCodePool = dataReader.findRawData(filePathForWorkFolderRawData,counties)
    #fileNamePool = ['2020ClaytonCountyEvictionCaseEvents-SCRAPE-09-25-2020','2020CobbCountyEvictionCaseEvents-SCRAPE-09-25-2020','2020DeKalbCountyEvictionCaseEvents-SCRAPE-09-25-2020','2020FultonCountyEvictionCaseEvents-SCRAPE-09-25-2020','2020GwinnettCountyEvictionCaseEvents-SCRAPE-09-25-2020'] 
    #countyCodePool = ['063','067','089','121','135']

    print(fileNamePool)

    for key, ele in enumerate(fileNamePool):

        countyName = ''
        for key2 in counties:
            if fileNamePool[key].find(counties[key2]) != -1:
                countyName = counties[key2] + ' County'

        rawDataIDAddressOnlyUnique = dataReader.ReadCSvAnddropDuplication(filePathForWorkFolderRawData, fileNamePool[key],counties)

#         display(rawDataIDAddressOnlyUnique)
        rawDataIDAddressOnlyUnique.to_csv('./test/'+countyName+'-cases.csv')
        

#         print(countyName,':',len(rawDataIDAddressOnlyUnique[rawDataIDAddressOnlyUnique['ifAnswered'] == 1]),'/',len(rawDataIDAddressOnlyUnique),'--',len(rawDataIDAddressOnlyUnique[rawDataIDAddressOnlyUnique['ifAnswered'] == 1])/len(rawDataIDAddressOnlyUnique))

# %%
test()
# Out:
# ['2020CobbCountyEvictionCaseEvents-SCRAPE-06-19-2021']

# %%
test()
# Out:
# ['2020ClaytonCountyEvictionCaseEvents-SCRAPE-06-19-2021', '2020CobbCountyEvictionCaseEvents-SCRAPE-06-19-2021', '2020DeKalbCountyEvictionCaseEvents-SCRAPE-06-19-2021', '2020FultonCountyEvictionCaseEvents-SCRAPE-06-19-2021', '2020GwinnettCountyEvictionCaseEvents-SCRAPE-06-19-2021']
#          fileDate       caseID  \
# 0      01/02/2020  2020CM00009
# 1      01/02/2020  2020CM00010
# 2      01/02/2020  2020CM00003
# 3      01/02/2020  2020CM00011
# 4      01/02/2020  2020CM00012
# ...           ...          ...
# 16364  06/18/2021  2021CM10559
# 16365  06/18/2021  2021CM10560
# 16366  06/18/2021  2021CM10561
# 16367  06/18/2021  2021CM10562
# 16368  06/18/2021  2021CM10563
#
#                                                plaintiff  \
# 0                                   5 AIF Nutmeg REO LLC
# 1      Bonneville Office Center dba Anthos at Chase R...
# 2                                         HAWKINS JEROME
# 3      Bonneville Office Center dba Anthos at Chase R...
# ...

# %%
def checkMonthlyCaseCount():
    with open('./config.json') as configFile:
        config = json.load(configFile)
    counties = config['counties']
    filePathForWorkFolderRawData = config['filePathForWorkFolderRawData']
    filePathForWorkFolderPreRawData = config['filePathForWorkFolderPreRawData']


    fileNamePool2,countyCodePool2 = dataReader.findRawData(filePathForWorkFolderPreRawData,counties)

    fileNamePool,countyCodePool = dataReader.findRawData(filePathForWorkFolderRawData,counties)

    my_headers = {'Authorization' : 'Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJyb2xlIiA6ICJ3ZWJ1c2VyIiwgInVzZXJfaWQiIDogMiwgImV4cCIgOiAxOTY2MjM3NTYzfQ.D5PuaEKMw2iFJgv9C634s1HOWHtAd-JHbttSPraJU8Y'}
    response = requests.get('http://evictions.design.gatech.edu/rest/atlanta_metro_area_cases', headers=my_headers)
    #     print(response.json()[0])
    #     df = pd.json_normalize(response.json())
    #     print(df.head(10))

    allData = {}
    # print('<br>')
    # print('<br>')
    print('Scraping Snapshot',': <br> ')

    for key, ele in enumerate(fileNamePool):
        # print('Pre Scraping: ')
        rawDataIDAddressOnlyUniquePre = pd.json_normalize(response.json())
        rawDataIDAddressOnlyUniquePre['fileDate'] = rawDataIDAddressOnlyUniquePre['filingdate']
        
        # print('Current Scraping: ')
        rawDataIDAddressOnlyUnique = dataReader.ReadCSvAnddropDuplication(filePathForWorkFolderRawData, fileNamePool[key],counties)

        for key2 in counties:
            if fileNamePool[key].find(counties[key2]) != -1:
                countyName = counties[key2] + ' County'
                rawDataIDAddressOnlyUniquePre = rawDataIDAddressOnlyUniquePre.loc[rawDataIDAddressOnlyUniquePre['county'] == key2]
      
        if countyName != "Cobb County":
            preSum = summarizedByMonthAPI(rawDataIDAddressOnlyUniquePre)
            currentSum = summarizedByMonth(rawDataIDAddressOnlyUnique)

            merged_df = preSum.merge(currentSum, how = 'right', on = ['month'])
        else:
            preSum = summarizedByMonthAPI(rawDataIDAddressOnlyUniquePre)
            currentSum = summarizedByMonthCobb(rawDataIDAddressOnlyUnique)

            merged_df = preSum.merge(currentSum, how = 'right', on = ['month'])
        merged_df = merged_df.fillna(0)

        # print(merged_df)
        allData[countyName]={}
        allData[countyName]['preTotal'] = rawDataIDAddressOnlyUniquePre.shape[0]
        allData[countyName]['currentTotal'] = rawDataIDAddressOnlyUnique.shape[0]
        allData[countyName]['df'] = merged_df


    # print("Monthly Count for scraping ",countyName, " (month --- pre_x --- current_y):")
    titleLine = '<tr><td>Filing Month/Year</td>'
    totalCountLine = '<tr><td></td>'
    countDict = {}
    for countyName in allData:
        titleLine = titleLine + '<td colspan="2">'+ countyName + '</td>'
        totalCountLine = totalCountLine + '<td>Database ('+ str(allData[countyName]['preTotal'])  +')</td><td>Raw Data ('+ str(allData[countyName]['currentTotal'])  +')</td>'

    # print('<br>')
    # print('<tr><td>Filing Month/Year</td><td colspan="2">',countyName,'</td></tr>')
    # print('<tr><td></td><td>PreScraping</td><td>CurrentScraping</td></tr>')
        for row in allData[countyName]['df'].values.tolist():
            if row[0] in countDict:
                countDict[row[0]] = countDict[row[0]] + row[1:]
            else:
                countDict[row[0]] = row[1:]

    titleLine = titleLine + '</tr>'
    totalCountLine = totalCountLine + '</tr>'
    print('<table>')
    print(titleLine)
    print(totalCountLine)
    for month in countDict:
        # newArray = [month] + countDict[month]
        print('<tr><td>',month,'</td>')
        for countIndex in range(len(countDict[month])):
            if countIndex % 2 == 1:
                if countDict[month][countIndex-1] > countDict[month][countIndex]:
                    print('<td bgcolor="pink">',countDict[month][countIndex],'</td>')
                else:
                    print('<td>',countDict[month][countIndex],'</td>')
            else:
                print('<td>',countDict[month][countIndex],'</td>')


        # print(*newArray, sep=' </td><td> ')
        print('</tr>')

                # print('<tr><td>')
                # print(*row, sep=' </td><td> ')
                # print('</td></tr>')
                # print('<br>')
        # print (merged_df)

    print('</table>')

    print('<br>')
    print('<br>')



        
def summarizedByMonthAPI (dfCounty):

    dfCounty["year"] = dfCounty['fileDate'].str.split("-").str[0]

    dfCounty = dfCounty[pd.to_numeric(dfCounty.year, errors='coerce').notnull()]

    dfCounty["year"] = pd.to_numeric(dfCounty["year"])

    dfCounty = dfCounty[dfCounty["year"] >= 2019]

    # build the column for month 
    dfCounty['month'] = dfCounty['fileDate'].str.split("-").str[1] + '-' +dfCounty['fileDate'].str.split("-").str[0]
    # count the cases for each month
    dfCounty = dfCounty.groupby(['month']).size().reset_index(name = "count")

    # # only take rows for year 2020 
    # df = df[df['fileDate'].str.strip().str[6:10] == '2020']

    # # build the column for month 
    # df['month'] = df['fileDate'].str.strip().str[0:2]

    # # count the cases for each month
    # df = df.groupby(['month']).size().reset_index(name = "count")

    return dfCounty

def summarizedByMonth (dfCounty):

    dfCounty["year"] = dfCounty['fileDate'].str.strip().str[6:10]

    dfCounty = dfCounty[pd.to_numeric(dfCounty.year, errors='coerce').notnull()]

    dfCounty["year"] = pd.to_numeric(dfCounty["year"])

    dfCounty = dfCounty[dfCounty["year"] >= 2019]

    # build the column for month 
    dfCounty['month'] = dfCounty['fileDate'].str.strip().str[0:2] + '-' +dfCounty['fileDate'].str.strip().str[6:10]
    # count the cases for each month
    dfCounty = dfCounty.groupby(['month']).size().reset_index(name = "count")

    # # only take rows for year 2020 
    # df = df[df['fileDate'].str.strip().str[6:10] == '2020']

    # # build the column for month 
    # df['month'] = df['fileDate'].str.strip().str[0:2]

    # # count the cases for each month
    # df = df.groupby(['month']).size().reset_index(name = "count")

    return dfCounty

def summarizedByMonthCobb (dfCounty):

    dfCounty["year"] = dfCounty['fileDate'].str.split("/").str[2]

    dfCounty = dfCounty[pd.to_numeric(dfCounty.year, errors='coerce').notnull()]

    dfCounty["year"] = pd.to_numeric(dfCounty["year"])

    dfCounty = dfCounty[dfCounty["year"] >= 19]

    # build the column for month 
    dfCounty['month'] = dfCounty['fileDate'].str.strip().str[0:2] + '-' +dfCounty['fileDate'].str.strip().str[6:10]
    dfCounty['month'][dfCounty['fileDate'].str.split("/").str[0].str.len()>1] = dfCounty['fileDate'].str.split("/").str[0] + '-' + "20" + dfCounty['fileDate'].str.split("/").str[2]
    dfCounty['month'][dfCounty['fileDate'].str.split("/").str[0].str.len()<=1] = "0"+ dfCounty['fileDate'].str.split("/").str[0] + '-' + "20" + dfCounty['fileDate'].str.split("/").str[2]
    # count the cases for each month

    # # only take rows for year 2020 
    # df = df[df['fileDate'].str.strip().str[-2:] == '20']

    # # build the column for month 


    # df['month'] = df['fileDate'].str.split("/").str[0]


    # count the cases for each month
    dfCounty = dfCounty.groupby(['month']).size().reset_index(name = "count")

    return dfCounty

# %%
checkMonthlyCaseCount()
# Out:
# Scraping Snapshot : <br>
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-9-c2d5b57976e6> in <module>()
# ----> 1 checkMonthlyCaseCount()
#
# <ipython-input-8-bcbe8cd69ca9> in checkMonthlyCaseCount()
#      28
#      29         # print('Current Scraping: ')
# ---> 30         rawDataIDAddressOnlyUnique = dataReader.ReadCSvAnddropDuplication(filePathForWorkFolderRawData, fileNamePool[key],counties)
#      31
#      32         for key2 in counties:
#
# D:\evictionProject\API\utils\dataReader.py in ReadCSvAnddropDuplication(filePath, fileName, counties)
#     173         rawDataIDAddressOnlyUnique = sortCasesByDateThenMostRecentCase(rawDataIDAddressOnlyUnique,validAnswerDict,'answerDate','ifAnswered','answerEventName')
# ...

# %% [markdown]
# Scraping Snapshot : <br>
# <table>
# <tr><td>Filing Month/Year</td><td colspan="2">Clayton County</td><td colspan="2">Cobb County</td><td colspan="2">DeKalb County</td><td colspan="2">Fulton County</td><td colspan="2">Gwinnett County</td></tr>
# <tr><td></td><td>Database (41726)</td><td>Raw Data (18742)</td><td>Database (41681)</td><td>Raw Data (19430)</td><td>Database (66611)</td><td>Raw Data (30385)</td><td>Database (87100)</td><td>Raw Data (41752)</td><td>Database (48182)</td><td>Raw Data (22347)</td></tr>
# <tr><td> 01-2020 </td>
# <td> 1996 </td>
# <td> 1996 </td>
# <td> 2265 </td>
# <td> 2265 </td>
# <td> 3204 </td>
# <td> 3204 </td>
# <td> 4326 </td>
# <td bgcolor="pink"> 4275 </td>
# <td> 2473 </td>
# <td> 2473 </td>
# </tr>
# <tr><td> 01-2021 </td>
# <td> 1037 </td>
# <td> 1037 </td>
# <td> 1126 </td>
# <td> 1126 </td>
# <td> 1764 </td>
# <td bgcolor="pink"> 1763 </td>
# <td> 2507 </td>
# <td> 2507 </td>
# <td> 1343 </td>
# <td> 1343 </td>
# </tr>
# <tr><td> 02-2020 </td>
# <td> 1977 </td>
# <td> 1977 </td>
# <td> 2073 </td>
# <td> 2073 </td>
# <td> 3008 </td>
# <td> 3008 </td>
# <td> 4005 </td>
# <td> 4005 </td>
# <td> 2291 </td>
# <td> 2291 </td>
# </tr>
# <tr><td> 02-2021 </td>
# <td> 1079 </td>
# <td> 1079 </td>
# <td> 974 </td>
# <td> 974 </td>
# <td> 1446 </td>
# <td> 1446 </td>
# <td> 2152 </td>
# <td> 2152 </td>
# <td> 1179 </td>
# <td> 1179 </td>
# </tr>
# <tr><td> 03-2020 </td>
# <td> 1086 </td>
# <td> 1086 </td>
# <td> 1239 </td>
# <td> 1239 </td>
# <td> 1916 </td>
# <td> 1916 </td>
# <td> 2622 </td>
# <td> 2622 </td>
# <td> 1517 </td>
# <td> 1517 </td>
# </tr>
# <tr><td> 03-2021 </td>
# <td> 755 </td>
# <td> 755 </td>
# <td> 1022 </td>
# <td> 1022 </td>
# <td> 1728 </td>
# <td> 1728 </td>
# <td> 2384 </td>
# <td> 2384 </td>
# <td> 1099 </td>
# <td> 1099 </td>
# </tr>
# <tr><td> 04-2020 </td>
# <td>
		rawDataIDAddressOnlyUniquePre = dataReader.ReadCSvAnddropDuplication(filePathForWorkFolderPreRawData, fileNamePool2[key],counties)

		# print('Current Scraping: ')
		rawDataIDAddressOnlyUnique = dataReader.ReadCSvAnddropDuplication(filePathForWorkFolderRawData, fileNamePool[key],counties)

		for key2 in counties:
			if fileNamePool[key].find(counties[key2]) != -1:
				countyName = counties[key2] + ' County'
		if countyName != "Cobb County":
			preSum = summarizedByMonth(rawDataIDAddressOnlyUniquePre)
			currentSum = summarizedByMonth(rawDataIDAddressOnlyUnique)

			merged_df = preSum.merge(currentSum, how = 'right', on = ['month'])
		else:
			preSum = summarizedByMonthCobb(rawDataIDAddressOnlyUniquePre)
			currentSum = summarizedByMonthCobb(rawDataIDAddressOnlyUnique)

			merged_df = preSum.merge(currentSum, how = 'right', on = ['month'])
		merged_df = merged_df.fillna(0)
	
		# print(merged_df)
		allData[countyName]={}
		allData[countyName]['preTotal'] = rawDataIDAddressOnlyUniquePre.shape[0]
		allData[countyName]['currentTotal'] = rawDataIDAddressOnlyUnique.shape[0]
		allData[countyName]['df'] = merged_df


	# print("Monthly Count for scraping ",countyName, " (month --- pre_x --- current_y):")
	titleLine = '<tr><td>Filing Month/Year</td>'
	totalCountLine = '<tr><td></td>'
	countDict = {}
	for countyName in allData:
		titleLine = titleLine + '<td colspan="2">'+ countyName + '</td>'
		totalCountLine = totalCountLine + '<td>PreScraping ('+ str(allData[countyName]['preTotal'])  +')</td><td>CurrentScraping ('+ str(allData[countyName]['currentTotal'])  +')</td>'

	# print('<br>')
	# print('<tr><td>Filing Month/Year</td><td colspan="2">',countyName,'</td></tr>')
	# print('<tr><td></td><td>PreScraping</td><td>CurrentScraping</td></tr>')
		for row in allData[countyName]['df'].values.tolist():
			if row[0] in countDict:
				countDict[row[0]] = countDict[row[0]] + row[1:]
			else:
				countDict[row[0]] = row[1:]

	titleLine = titleLine + '</tr>'
	totalCountLine = totalCountLine + '</tr>'
	print('<table>')
	print(titleLine)
	print(totalCountLine)
	for month in countDict:
		# newArray = [month] + countDict[month]
		print('<tr><td>',month,'</td>')
		for countIndex in range(len(countDict[month])):
			if countIndex % 2 == 1:
				if countDict[month][countIndex-1] > countDict[month][countIndex]:
					print('<td bgcolor="pink">',countDict[month][countIndex],'</td>')
				else:
					print('<td>',countDict[month][countIndex],'</td>')
			else:
				print('<td>',countDict[month][countIndex],'</td>')


		# print(*newArray, sep=' </td><td> ')
		print('</tr>')

				# print('<tr><td>')
				# print(*row, sep=' </td><td> ')
				# print('</td></tr>')
				# print('<br>')
		# print (merged_df)
		
	print('</table>')

	print('<br>')
	print('<br>')
		
	
		
def summarizedByMonth (dfCounty):

	dfCounty["year"] = dfCounty['fileDate'].str.strip().str[6:10]

	dfCounty = dfCounty[pd.to_numeric(dfCounty.year, errors='coerce').notnull()]

	dfCounty["year"] = pd.to_numeric(dfCounty["year"])

	dfCounty = dfCounty[dfCounty["year"] >= 2020]

	# build the column for month 
	dfCounty['month'] = dfCounty['fileDate'].str.strip().str[0:2] + '-' +dfCounty['fileDate'].str.strip().str[6:10]
	# count the cases for each month
	dfCounty = dfCounty.groupby(['month']).size().reset_index(name = "count")

	# # only take rows for year 2020 
	# df = df[df['fileDate'].str.strip().str[6:10] == '2020']

	# # build the column for month 
	# df['month'] = df['fileDate'].str.strip().str[0:2]

	# # count the cases for each month
	# df = df.groupby(['month']).size().reset_index(name = "count")

	return dfCounty

def summarizedByMonthCobb (dfCounty):

	dfCounty["year"] = dfCounty['fileDate'].str.split("/").str[2]

	dfCounty = dfCounty[pd.to_numeric(dfCounty.year, errors='coerce').notnull()]

	dfCounty["year"] = pd.to_numeric(dfCounty["year"])

	dfCounty = dfCounty[dfCounty["year"] >= 20]

	# build the column for month 
	dfCounty['month'] = dfCounty['fileDate'].str.strip().str[0:2] + '-' +dfCounty['fileDate'].str.strip().str[6:10]
	dfCounty['month'][dfCounty['fileDate'].str.split("/").str[0].str.len()>1] = dfCounty['fileDate'].str.split("/").str[0] + '-' + "20" + dfCounty['fileDate'].str.split("/").str[2]
	dfCounty['month'][dfCounty['fileDate'].str.split("/").str[0].str.len()<=1] = "0"+ dfCounty['fileDate'].str.split("/").str[0] + '-' + "20" + dfCounty['fileDate'].str.split("/").str[2]
	# count the cases for each month

	# # only take rows for year 2020 
	# df = df[df['fileDate'].str.strip().str[-2:] == '20']

	# # build the column for month 

	
	# df['month'] = df['fileDate'].str.split("/").str[0]
	

	# count the cases for each month
	dfCounty = dfCounty.groupby(['month']).size().reset_index(name = "count")

	return dfCounty

# %%
checkMonthlyCaseCount()
# Out:
# Scraping Snapshot : <br>
# <table>
# <tr><td>Filing Month/Year</td><td colspan="2">Cobb County</td></tr>
# <tr><td></td><td>PreScraping (16261)</td><td>CurrentScraping (16791)</td></tr>
# <tr><td> 01-2020 </td>
# <td> 2265.0 </td>
# <td> 2265 </td>
# </tr>
# <tr><td> 01-2021 </td>
# <td> 1126.0 </td>
# <td> 1126 </td>
# </tr>
# <tr><td> 02-2020 </td>
# <td> 2073.0 </td>
# <td> 2073 </td>
# </tr>
# <tr><td> 02-2021 </td>
# <td> 974.0 </td>
# <td> 974 </td>
# </tr>
# <tr><td> 03-2020 </td>
# <td> 1239.0 </td>
# <td> 1239 </td>
# </tr>
# <tr><td> 03-2021 </td>
# <td> 1022.0 </td>
# <td> 1022 </td>
# </tr>
# <tr><td> 04-2020 </td>
# <td> 110.0 </td>
# <td> 110 </td>
# </tr>
# <tr><td> 04-2021 </td>
# <td> 905.0 </td>
# <td> 905 </td>
# </tr>
# <tr><td> 05-2020 </td>
# <td> 113.0 </td>
# <td> 113 </td>
# </tr>
# <tr><td> 05-2021 </td>
# <td> 816.0 </td>
# <td> 816 </td>
# </tr>
# <tr><td> 06-2020 </td>
# <td> 197.0 </td>
# <td> 197 </td>
# </tr>
# <tr><td> 06-2021 </td>
# ...

# %% [markdown]
# Scraping Snapshot : <br>
# <table>
# <tr><td>Filing Month/Year</td><td colspan="2">Cobb County</td></tr>
# <tr><td></td><td>PreScraping (16261)</td><td>CurrentScraping (16688)</td></tr>
# <tr><td> 01-2020 </td>
# <td> 2265.0 </td>
# <td> 2265 </td>
# </tr>
# <tr><td> 01-2021 </td>
# <td> 1126.0 </td>
# <td> 1126 </td>
# </tr>
# <tr><td> 02-2020 </td>
# <td> 2073.0 </td>
# <td> 2073 </td>
# </tr>
# <tr><td> 02-2021 </td>
# <td> 974.0 </td>
# <td> 974 </td>
# </tr>
# <tr><td> 03-2020 </td>
# <td> 1239.0 </td>
# <td> 1239 </td>
# </tr>
# <tr><td> 03-2021 </td>
# <td> 1022.0 </td>
# <td> 1022 </td>
# </tr>
# <tr><td> 04-2020 </td>
# <td> 110.0 </td>
# <td> 110 </td>
# </tr>
# <tr><td> 04-2021 </td>
# <td> 905.0 </td>
# <td bgcolor="pink"> 904 </td>
# </tr>
# <tr><td> 05-2020 </td>
# <td> 113.0 </td>
# <td> 113 </td>
# </tr>
# <tr><td> 05-2021 </td>
# <td> 816.0 </td>
# <td> 816 </td>
# </tr>
# <tr><td> 06-2020 </td>
# <td> 197.0 </td>
# <td> 197 </td>
# </tr>
# <tr><td> 06-2021 </td>
# <td> 610.0 </td>
# <td> 994 </td>
# </tr>
# <tr><td> 07-2020 </td>
# <td> 258.0 </td>
# <td> 258 </td>
# </tr>
# <tr><td> 08-2020 </td>
# <td> 426.0 </td>
# <td> 426 </td>
# </tr>
# <tr><td> 09-2020 </td>
# <td> 904.0 </td>
# <td> 904 </td>
# </tr>
# <tr><td> 10-2020 </td>
# <td> 956.0 </td>
# <td> 956 </td>
# </tr>
# <tr><td> 11-2020 </td>
# <td> 1093.0 </td>
# <td> 1093 </td>
# </tr>
# <tr><td> 12-2020 </td>
# <td> 1170.0 </td>
# <td> 1170 </td>
# </tr>
# <tr><td> 07-2021 </td>
# <td> 0.0 </td>
# <td> 44 </td>
# </tr>
# </table>
# <br>
# <br>
#  </td>

# %% [markdown]
# Scraping Snapshot : <br>
# <table>
# <tr><td>Filing Month/Year</td><td colspan="2">Cobb County</td></tr>
# <tr><td></td><td>PreScraping (16261)</td><td>CurrentScraping (16791)</td></tr>
# <tr><td> 01-2020 </td>
# <td> 2265.0 </td>
# <td> 2265 </td>
# </tr>
# <tr><td> 01-2021 </td>
# <td> 1126.0 </td>
# <td> 1126 </td>
# </tr>
# <tr><td> 02-2020 </td>
# <td> 2073.0 </td>
# <td> 2073 </td>
# </tr>
# <tr><td> 02-2021 </td>
# <td> 974.0 </td>
# <td> 974 </td>
# </tr>
# <tr><td> 03-2020 </td>
# <td> 1239.0 </td>
# <td> 1239 </td>
# </tr>
# <tr><td> 03-2021 </td>
# <td> 1022.0 </td>
# <td> 1022 </td>
# </tr>
# <tr><td> 04-2020 </td>
# <td> 110.0 </td>
# <td> 110 </td>
# </tr>
# <tr><td> 04-2021 </td>
# <td> 905.0 </td>
# <td> 905 </td>
# </tr>
# <tr><td> 05-2020 </td>
# <td> 113.0 </td>
# <td> 113 </td>
# </tr>
# <tr><td> 05-2021 </td>
# <td> 816.0 </td>
# <td> 816 </td>
# </tr>
# <tr><td> 06-2020 </td>
# <td> 197.0 </td>
# <td> 197 </td>
# </tr>
# <tr><td> 06-2021 </td>
# <td> 610.0 </td>
# <td> 994 </td>
# </tr>
# <tr><td> 07-2020 </td>
# <td> 258.0 </td>
# <td> 258 </td>
# </tr>
# <tr><td> 08-2020 </td>
# <td> 426.0 </td>
# <td> 426 </td>
# </tr>
# <tr><td> 09-2020 </td>
# <td> 904.0 </td>
# <td> 904 </td>
# </tr>
# <tr><td> 10-2020 </td>
# <td> 956.0 </td>
# <td> 956 </td>
# </tr>
# <tr><td> 11-2020 </td>
# <td> 1093.0 </td>
# <td> 1093 </td>
# </tr>
# <tr><td> 12-2020 </td>
# <td> 1170.0 </td>
# <td> 1170 </td>
# </tr>
# <tr><td> 07-2021 </td>
# <td> 0.0 </td>
# <td> 146 </td>
# </tr>
# </table>
# <br>
# <br>

# %%
def checkMonthlyCaseCount():
	with open('./config.json') as configFile:
		config = json.load(configFile)
	counties = config['counties']
	filePathForWorkFolderRawData = config['filePathForWorkFolderRawData']
	filePathForWorkFolderPreRawData = config['filePathForWorkFolderPreRawData']

	
	fileNamePool2,countyCodePool2 = dataReader.findRawData(filePathForWorkFolderPreRawData,counties)
	
	fileNamePool,countyCodePool = dataReader.findRawData(filePathForWorkFolderRawData,counties)

	allData = {}
	# print('<br>')
	# print('<br>')
	print('Answered Cases Analysis from Raw Data',': <br> ')

	for key, ele in enumerate(fileNamePool):
		# print('Pre Scraping: ')
		

		# print('Current Scraping: ')
		rawDataIDAddressOnlyUnique = dataReader.ReadCSvAnddropDuplication(filePathForWorkFolderRawData, fileNamePool[key],counties)
        
		rawDataIDAddressOnlyUniquePre = rawDataIDAddressOnlyUnique[rawDataIDAddressOnlyUnique['ifAnswered'] == 1]

		for key2 in counties:
			if fileNamePool[key].find(counties[key2]) != -1:
				countyName = counties[key2] + ' County'
		if countyName != "Cobb County":
			preSum = summarizedByMonth(rawDataIDAddressOnlyUniquePre)
			currentSum = summarizedByMonth(rawDataIDAddressOnlyUnique)

			merged_df = preSum.merge(currentSum, how = 'right', on = ['month'])
		else:
			preSum = summarizedByMonthCobb(rawDataIDAddressOnlyUniquePre)
			currentSum = summarizedByMonthCobb(rawDataIDAddressOnlyUnique)

			merged_df = preSum.merge(currentSum, how = 'right', on = ['month'])
		merged_df = merged_df.fillna(0)
	
# 		print(merged_df)
		merged_df['rate'] = merged_df['count_x']/merged_df['count_y']*100
		merged_df['rate'] = merged_df['rate'].astype(int)
		merged_df['rate'] = merged_df['rate'].astype(str) + '%'
		allData[countyName]={}
		allData[countyName]['preTotal'] = rawDataIDAddressOnlyUniquePre.shape[0]
		allData[countyName]['currentTotal'] = rawDataIDAddressOnlyUnique.shape[0]
		allData[countyName]['df'] = merged_df


	# print("Monthly Count for scraping ",countyName, " (month --- pre_x --- current_y):")
	titleLine = '<tr><td>Filing Month/Year</td>'
	totalCountLine = '<tr><td></td>'
	countDict = {}
	for countyName in allData:
		titleLine = titleLine + '<td colspan="3">'+ countyName + '</td>'
		totalCountLine = totalCountLine + '<td>Answered ('+ str(allData[countyName]['preTotal'])  +')</td><td>All ('+ str(allData[countyName]['currentTotal'])  +')</td><td>Rate ('+ str(int(allData[countyName]['preTotal']/allData[countyName]['currentTotal']*100))  +'%)</td>'

	# print('<br>')
	# print('<tr><td>Filing Month/Year</td><td colspan="2">',countyName,'</td></tr>')
	# print('<tr><td></td><td>PreScraping</td><td>CurrentScraping</td></tr>')
		for row in allData[countyName]['df'].values.tolist():
			if row[0] in countDict:
				countDict[row[0]] = countDict[row[0]] + row[1:]
			else:
				countDict[row[0]] = row[1:]

	titleLine = titleLine + '</tr>'
	totalCountLine = totalCountLine + '</tr>'
	print('<table>')
	print(titleLine)
	print(totalCountLine)
	for month in countDict:
		# newArray = [month] + countDict[month]
		print('<tr><td>',month,'</td>')
		for countIndex in range(len(countDict[month])):
# 			if countIndex % 2 == 1:
# 				if countDict[month][countIndex-1] > countDict[month][countIndex]:
# 					print('<td bgcolor="pink">',countDict[month][countIndex],'</td>')
# 				else:
# 					print('<td>',countDict[month][countIndex],'</td>')
# 			else:
			print('<td>',countDict[month][countIndex],'</td>')


		# print(*newArray, sep=' </td><td> ')
		print('</tr>')

				# print('<tr><td>')
				# print(*row, sep=' </td><td> ')
				# print('</td></tr>')
				# print('<br>')
		# print (merged_df)
		
	print('</table>')

	print('<br>')
	print('<br>')
		
	
		
def summarizedByMonth (dfCounty):

	dfCounty["year"] = dfCounty['fileDate'].str.strip().str[6:10]

	dfCounty = dfCounty[pd.to_numeric(dfCounty.year, errors='coerce').notnull()]

	dfCounty["year"] = pd.to_numeric(dfCounty["year"])

	dfCounty = dfCounty[dfCounty["year"] >= 2020]

	# build the column for month 
	dfCounty['month'] = dfCounty['fileDate'].str.strip().str[0:2] + '-' +dfCounty['fileDate'].str.strip().str[6:10]
	# count the cases for each month
	dfCounty = dfCounty.groupby(['month']).size().reset_index(name = "count")

	# # only take rows for year 2020 
	# df = df[df['fileDate'].str.strip().str[6:10] == '2020']

	# # build the column for month 
	# df['month'] = df['fileDate'].str.strip().str[0:2]

	# # count the cases for each month
	# df = df.groupby(['month']).size().reset_index(name = "count")

	return dfCounty

def summarizedByMonthCobb (dfCounty):

	dfCounty["year"] = dfCounty['fileDate'].str.split("/").str[2]

	dfCounty = dfCounty[pd.to_numeric(dfCounty.year, errors='coerce').notnull()]

	dfCounty["year"] = pd.to_numeric(dfCounty["year"])

	dfCounty = dfCounty[dfCounty["year"] >= 20]

	# build the column for month 
	dfCounty['month'] = dfCounty['fileDate'].str.strip().str[0:2] + '-' +dfCounty['fileDate'].str.strip().str[6:10]
	dfCounty['month'][dfCounty['fileDate'].str.split("/").str[0].str.len()>1] = dfCounty['fileDate'].str.split("/").str[0] + '-' + "20" + dfCounty['fileDate'].str.split("/").str[2]
	dfCounty['month'][dfCounty['fileDate'].str.split("/").str[0].str.len()<=1] = "0"+ dfCounty['fileDate'].str.split("/").str[0] + '-' + "20" + dfCounty['fileDate'].str.split("/").str[2]
	# count the cases for each month

	# # only take rows for year 2020 
	# df = df[df['fileDate'].str.strip().str[-2:] == '20']

	# # build the column for month 

	
	# df['month'] = df['fileDate'].str.split("/").str[0]
	

	# count the cases for each month
	dfCounty = dfCounty.groupby(['month']).size().reset_index(name = "count")

	return dfCounty

# %%
checkMonthlyCaseCount()
# Out:
# Answered Cases Analysis from Raw Data : <br>
# <table>
# <tr><td>Filing Month/Year</td><td colspan="3">Cobb County</td></tr>
# <tr><td></td><td>Answered (4948)</td><td>All (16261)</td><td>Rate (30%)</td></tr>
# <tr><td> 01-2020 </td>
# <td> 653 </td>
# <td> 2265 </td>
# <td> 28% </td>
# </tr>
# <tr><td> 01-2021 </td>
# <td> 401 </td>
# <td> 1126 </td>
# <td> 35% </td>
# </tr>
# <tr><td> 02-2020 </td>
# <td> 517 </td>
# <td> 2073 </td>
# <td> 24% </td>
# </tr>
# <tr><td> 02-2021 </td>
# <td> 308 </td>
# <td> 974 </td>
# <td> 31% </td>
# </tr>
# <tr><td> 03-2020 </td>
# <td> 245 </td>
# <td> 1239 </td>
# <td> 19% </td>
# </tr>
# <tr><td> 03-2021 </td>
# <td> 310 </td>
# <td> 1022 </td>
# <td> 30% </td>
# </tr>
# <tr><td> 04-2020 </td>
# <td> 29 </td>
# <td> 110 </td>
# <td> 26% </td>
# </tr>
# <tr><td> 04-2021 </td>
# <td> 313 </td>
# <td> 905 </td>
# <td> 34% </td>
# </tr>
# <tr><td> 05-2020 </td>
# <td> 31 </td>
# <td> 113 </td>
# <td> 27% </td>
# </tr>
# <tr><td> 05-2021 </td>
# ...

# %% [markdown]
# Answered Cases Analysis from Raw Data : <br>
# <table>
# <tr><td>Filing Month/Year</td><td colspan="3">Clayton County</td><td colspan="3">Cobb County</td><td colspan="3">DeKalb County</td><td colspan="3">Fulton County</td><td colspan="3">Gwinnett County</td></tr>
# <tr><td></td><td>Answered (4479)</td><td>All (15929)</td><td>Rate (28%)</td><td>Answered (4919)</td><td>All (15868)</td><td>Rate (30%)</td><td>Answered (7766)</td><td>All (25291)</td><td>Rate (30%)</td><td>Answered (10988)</td><td>All (34725)</td><td>Rate (31%)</td><td>Answered (4154)</td><td>All (18559)</td><td>Rate (22%)</td></tr>
'Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJyb2xlIiA6ICJ3ZWJ1c2VyIiwgInVzZXJfaWQiIDogMiwgImV4cCIgOiAxOTY2MjM3NTYzfQ.D5PuaEKMw2iFJgv9C634s1HOWHtAd-JHbttSPraJU8Y'}
response = requests.get('http://evictions.design.gatech.edu/rest/atlanta_metro_area_cases', headers=my_headers)
print(response.json()[0])
df = pd.json_normalize(response.json())
print(df.head(10))
# Out:
# {'id': '2020CM0000313063040516063', 'street': '235 horseshoe bnd', 'city': '  riverdale', 'zip': '  30274', 'filingdate': '2020-01-02', 'answer': '0', 'county': '063', 'latitude': '33.54092685', 'longitude': '-84.39800183', 'services': '1', 'dismiss': '0', 'defaultjudgment': '0', 'judgment': '0', 'answerdate': '9999-12-12', 'servicesdate': '2020-01-07', 'dismissdate': '9999-12-12', 'defaultjudgmentdate': '9999-12-12', 'judgmentdate': '9999-12-12', 'tractid': '13063040516', 'blockgroupid': '130630405161'}
#                           id                street           city      zip  \
# 0  2020CM0000313063040516063     235 horseshoe bnd      riverdale    30274
# 1  2020CM0001013063040514063    100 chase ridge dr      riverdale    30296
# 2  2020CM0001113063040514063    100 chase ridge dr      riverdale    30296
# 3  2020CM0001213063040514063    100 chase ridge dr      riverdale    30296
# 4  2020CM0001313063040609063   817 fieldstone pkwy      jonesboro    30236
# ...

# %%
for case in response.json():
    if case['county'] == '':
        print (case)
# Out:
# {'id': '20-M-0144199999999999', 'street': '917 boulevard', 'city': '  athens', 'zip': '  30601', 'filingdate': '2020-01-13', 'answer': '0', 'county': '', 'latitude': '33.966280600000005', 'longitude': '-83.39717982', 'services': None, 'dismiss': None, 'defaultjudgment': None, 'judgment': None, 'answerdate': None, 'servicesdate': None, 'dismissdate': None, 'defaultjudgmentdate': None, 'judgmentdate': None, 'tractid': None, 'blockgroupid': None}
# {'id': '20-M-0144299999999999', 'street': '408 boulevard', 'city': '  lagrange', 'zip': '  30240', 'filingdate': '2020-01-13', 'answer': '0', 'county': '', 'latitude': '33.03372888', 'longitude': '-85.0398443', 'services': None, 'dismiss': None, 'defaultjudgment': None, 'judgment': None, 'answerdate': None, 'servicesdate': None, 'dismissdate': None, 'defaultjudgmentdate': None, 'judgmentdate': None, 'tractid': None, 'blockgroupid': None}
# ...

# %%
globalStatsDict = {}
for case in response.json():
    if case['county'] != '':
        if case['county'] in globalStatsDict:
            
            globalStatsDict[case['county']]['all'] += 1
            if case['services'] == '1':
                globalStatsDict[case['county']]['services'] += 1

            if case['dismiss'] == '1':
                globalStatsDict[case['county']]['dismiss'] += 1

            if case['answer'] == '1':
                globalStatsDict[case['county']]['answer'] += 1

            if case['defaultjudgment'] == '1':
                globalStatsDict[case['county']]['defaultjudgment'] += 1

            if case['judgment'] == '1':
                globalStatsDict[case['county']]['judgment'] += 1
        else:
            globalStatsDict[case['county']]={}
            
            globalStatsDict[case['county']]['all'] = 1
            
            if case['services'] == '1':
                globalStatsDict[case['county']]['services'] = 1
            else:
                globalStatsDict[case['county']]['services'] = 0

            if case['dismiss'] == '1':
                globalStatsDict[case['county']]['dismiss'] = 1
            else:
                globalStatsDict[case['county']]['dismiss'] = 0

            if case['answer'] == '1':
                globalStatsDict[case['county']]['answer'] = 1
            else:
                globalStatsDict[case['county']]['answer'] = 0

            if case['defaultjudgment'] == '1':
                globalStatsDict[case['county']]['defaultjudgment'] = 1
            else:
                globalStatsDict[case['county']]['defaultjudgment'] = 0

            if case['judgment'] == '1':
                globalStatsDict[case['county']]['judgment'] = 1
            else:
                globalStatsDict[case['county']]['judgment'] = 0

# %%
statsDict = {}
for case in response.json():
#     print(case['filingdate'].split('-'))
    if case['county'] != '':
        if case['county'] in statsDict:
            if case['filingdate'].split('-')[0]+'-'+case['filingdate'].split('-')[1] in statsDict[case['county']]:
                statsDict[case['county']][case['filingdate'].split('-')[0]+'-'+case['filingdate'].split('-')[1]]['all'] += 1
                if case['services'] == '1':
                    statsDict[case['county']][case['filingdate'].split('-')[0]+'-'+case['filingdate'].split('-')[1]]['services'] += 1

                if case['dismiss'] == '1':
                    statsDict[case['county']][case['filingdate'].split('-')[0]+'-'+case['filingdate'].split('-')[1]]['dismiss'] += 1

                if case['answer'] == '1':
                    statsDict[case['county']][case['filingdate'].split('-')[0]+'-'+case['filingdate'].split('-')[1]]['answer'] += 1

                if case['defaultjudgment'] == '1':
                    statsDict[case['county']][case['filingdate'].split('-')[0]+'-'+case['filingdate'].split('-')[1]]['defaultjudgment'] += 1

                if case['judgment'] == '1':
                    statsDict[case['county']][case['filingdate'].split('-')[0]+'-'+case['filingdate'].split('-')[1]]['judgment'] += 1
            else:
                statsDict[case['county']][case['filingdate'].split('-')[0]+'-'+case['filingdate'].split('-')[1]] = {}
                
                if case['answer'] == '1':
                    statsDict[case['county']][case['filingdate'].split('-')[0]+'-'+case['filingdate'].split('-')[1]]['answer'] = 1
                else:
                    statsDict[case['county']][case['filingdate'].split('-')[0]+'-'+case['filingdate'].split('-')[1]]['answer'] = 0

                if case['services'] == '1':
                    statsDict[case['county']][case['filingdate'].split('-')[0]+'-'+case['filingdate'].split('-')[1]]['services'] = 1
                else:
                    statsDict[case['county']][case['filingdate'].split('-')[0]+'-'+case['filingdate'].split('-')[1]]['services'] = 0

                if case['dismiss'] == '1':
                    statsDict[case['county']][case['filingdate'].split('-')[0]+'-'+case['filingdate'].split('-')[1]]['dismiss'] = 1
                else:
                    statsDict[case['county']][case['filingdate'].split('-')[0]+'-'+case['filingdate'].split('-')[1]]['dismiss'] = 0

                

                if case['defaultjudgment'] == '1':
                    statsDict[case['county']][case['filingdate'].split('-')[0]+'-'+case['filingdate'].split('-')[1]]['defaultjudgment'] = 1
                else:
                    statsDict[case['county']][case['filingdate'].split('-')[0]+'-'+case['filingdate'].split('-')[1]]['defaultjudgment'] = 0

                if case['judgment'] == '1':
                    statsDict[case['county']][case['filingdate'].split('-')[0]+'-'+case['filingdate'].split('-')[1]]['judgment'] = 1
                else:
                    statsDict[case['county']][case['filingdate'].split('-')[0]+'-'+case['filingdate'].split('-')[1]]['judgment'] = 0
                    
                statsDict[case['county']][case['filingdate'].split('-')[0]+'-'+case['filingdate'].split('-')[1]]['all'] = 1
        else:
            statsDict[case['county']]={}
            
            statsDict[case['county']][case['filingdate'].split('-')[0]+'-'+case['filingdate'].split('-')[1]] = {}
            
            if case['answer'] == '1':
                statsDict[case['county']][case['filingdate'].split('-')[0]+'-'+case['filingdate'].split('-')[1]]['answer'] = 1
            else:
                statsDict[case['county']][case['filingdate'].split('-')[0]+'-'+case['filingdate'].split('-')[1]]['answer'] = 0
                
            if case['services'] == '1':
                statsDict[case['county']][case['filingdate'].split('-')[0]+'-'+case['filingdate'].split('-')[1]]['services'] = 1
            else:
                statsDict[case['county']][case['filingdate'].split('-')[0]+'-'+case['filingdate'].split('-')[1]]['services'] = 0

            if case['dismiss'] == '1':
                statsDict[case['county']][case['filingdate'].split('-')[0]+'-'+case['filingdate'].split('-')[1]]['dismiss'] = 1
            else:
                statsDict[case['county']][case['filingdate'].split('-')[0]+'-'+case['filingdate'].split('-')[1]]['dismiss'] = 0

            if case['defaultjudgment'] == '1':
                statsDict[case['county']][case['filingdate'].split('-')[0]+'-'+case['filingdate'].split('-')[1]]['defaultjudgment'] = 1
            else:
                statsDict[case['county']][case['filingdate'].split('-')[0]+'-'+case['filingdate'].split('-')[1]]['defaultjudgment'] = 0

            if case['judgment'] == '1':
                statsDict[case['county']][case['filingdate'].split('-')[0]+'-'+case['filingdate'].split('-')[1]]['judgment'] = 1
            else:
                statsDict[case['county']][case['filingdate'].split('-')[0]+'-'+case['filingdate'].split('-')[1]]['judgment'] = 0
                
            statsDict[case['county']][case['filingdate'].split('-')[0]+'-'+case['filingdate'].split('-')[1]]['all'] = 1

# %%
print(globalStatsDict)
print(statsDict)
# Out:
# {'121': {'all': 35472, 'services': 32435, 'dismiss': 17207, 'answer': 11069, 'defaultjudgment': 1616, 'judgment': 8816}, '089': {'all': 25996, 'services': 24022, 'dismiss': 9933, 'answer': 7845, 'defaultjudgment': 87, 'judgment': 5898}, '063': {'all': 16369, 'services': 15228, 'dismiss': 8, 'answer': 4526, 'defaultjudgment': 0, 'judgment': 1071}, '135': {'all': 19168, 'services': 16178, 'dismiss': 10287, 'answer': 4229, 'defaultjudgment': 633, 'judgment': 5887}, '067': {'all': 16269, 'services': 15757, 'dismiss': 7579, 'answer': 4956, 'defaultjudgment': 325, 'judgment': 3125}}
# ...

# %%
counties= {
    "063":"Clayton",
    "067":"Cobb",
    "089":"DeKalb",
    "121":"Fulton",
    "135":"Gwinnett"
}
for key in counties:

    titleLine = '<tr><td>Filing Month/Year</td>'
    totalCountLine = '<tr><td></td>'
    titleLine = titleLine + '<td colspan="6">'+ counties[key] + '</td>'
    totalCountLine = totalCountLine + '<td>Answered ('+ str(globalStatsDict[key]['answer'])  +')</td>'+ '<td>Serviced ('+ str(globalStatsDict[key]['services'])  +')</td>'+'<td>Dismissed ('+ str(globalStatsDict[key]['dismiss'])  +')</td>'+'<td>defaultjudgment ('+ str(globalStatsDict[key]['defaultjudgment'])  +')</td>'+'<td>Judged ('+ str(globalStatsDict[key]['judgment'])  +')</td>' +'<td>All ('+ str(globalStatsDict[key]['all'])+')</td>'

    # print('<br>')
    # print('<tr><td>Filing Month/Year</td><td colspan="2">',countyName,'</td></tr>')
    # print('<tr><td></td><td>PreScraping</td><td>CurrentScraping</td></tr>')

    titleLine = titleLine + '</tr>'
    totalCountLine = totalCountLine + '</tr>'
    print('<table>')
    print(titleLine)
    print(totalCountLine)
    for month in statsDict[key]:
        # newArray = [month] + countDict[month]
        print('<tr><td>',month,'</td>')
        for countIndex in statsDict[key][month]:
            print('<td>',statsDict[key][month][countIndex],'</td>')

        print('</tr>')

    print('</table>')

    print('<br>')
    print('<br>')
# Out:
# <table>
# <tr><td>Filing Month/Year</td><td colspan="6">Clayton</td></tr>
# <tr><td></td><td>Answered (4526)</td><td>Serviced (15228)</td><td>Dismissed (8)</td><td>defaultjudgment (0)</td><td>Judged (1071)</td><td>All (16369)</td></tr>
# <tr><td> 2020-01 </td>
# <td> 667 </td>
# <td> 1995 </td>
# <td> 0 </td>
# <td> 0 </td>
# <td> 488 </td>
# <td> 1996 </td>
# </tr>
# <tr><td> 2020-02 </td>
# <td> 579 </td>
# <td> 1966 </td>
# <td> 0 </td>
# <td> 0 </td>
# <td> 370 </td>
# <td> 1977 </td>
# </tr>
# <tr><td> 2020-03 </td>
# <td> 132 </td>
# <td> 667 </td>
# <td> 0 </td>
# <td> 0 </td>
# <td> 18 </td>
# <td> 1086 </td>
# </tr>
# <tr><td> 2020-04 </td>
# <td> 14 </td>
# <td> 35 </td>
# <td> 0 </td>
# <td> 0 </td>
# <td> 3 </td>
# <td> 229 </td>
# </tr>
# <tr><td> 2020-05 </td>
# <td> 24 </td>
# <td> 73 </td>
# <td> 0 </td>
# <td> 0 </td>
# <td> 5 </td>
# <td> 195 </td>
# </tr>
# <tr><td> 2020-06 </td>
# <td> 60 </td>
# <td> 256 </td>
# <td> 0 </td>
# <td> 0 </td>
# <td> 15 </td>
# ...

# %% [markdown]
# <table>
# <tr><td>Filing Month/Year</td><td colspan="6">Clayton</td></tr>
# <tr><td></td><td>Answered (4526)</td><td>Serviced (15228)</td><td>Dismissed (8)</td><td>defaultjudgment (0)</td><td>Judged (1071)</td><td>All (16369)</td></tr>
# <tr><td> 2020-01 </td>
# <td> 667 </td>
# <td> 1995 </td>
# <td> 0 </td>
# <td> 0 </td>
# <td> 488 </td>
# <td> 1996 </td>
# </tr>
# <tr><td> 2020-02 </td>
# <td> 579 </td>
# <td> 1966 </td>
# <td> 0 </td>
# <td> 0 </td>
# <td> 370 </td>
# <td> 1977 </td>
# </tr>
# <tr><td> 2020-03 </td>
# <td> 132 </td>
# <td> 667 </td>
# <td> 0 </td>
# <td> 0 </td>
# <td> 18 </td>
# <td> 1086 </td>
# </tr>
# <tr><td> 2020-04 </td>
# <td> 14 </td>
# <td> 35 </td>
# <td> 0 </td>
# <td> 0 </td>
# <td> 3 </td>
# <td> 229 </td>
# </tr>
# <tr><td> 2020-05 </td>
# <td> 24 </td>
# <td> 73 </td>
# <td> 0 </td>
# <td> 0 </td>
# <td> 5 </td>
# <td> 195 </td>
# </tr>
# <tr><td> 2020-06 </td>
# <td> 60 </td>
# <td> 256 </td>
# <td> 0 </td>
# <td> 0 </td>
# <td> 15 </td>
# <td> 404 </td>
# </tr>
# <tr><td> 2020-07 </td>
# <td> 97 </td>
# <td> 417 </td>
# <td> 0 </td>
# <td> 0 </td>
# <td> 30 </td>
# <td> 472 </td>
# </tr>
# <tr><td> 2020-08 </td>
# <td> 142 </td>
# <td> 501 </td>
# <td> 1 </td>
# <td> 0 </td>
# <td> 34 </td>
# <td> 512 </td>
# </tr>
# <tr><td> 2020-09 </td>
# <td> 313 </td>
# <td> 1067 </td>
# <td> 4 </td>
# <td> 0 </td>
# <td> 34 </td>
# <td> 1069 </td>
# </tr>
# <tr><td> 2020-10 </td>
# <td> 354 </td>
# <td> 1019 </td>
# <td> 3 </td>
# <td> 0 </td>
# <td> 24 </td>
# <td> 1020 </td>
# </tr>
# <tr><td> 2020-11 </td>
# <td> 427 </td>
# <td> 1218 </td>
# <td> 0 </td>
# <td> 0 </td>
# <td> 24 </td>
# <td> 1220 </td>
# </tr>
# <tr><td> 2020-12 </td>
# <td> 387 </td>
# <td> 1199 </td>
# <td> 0 </td>
# <td> 0 </td>
# <td>
# </tr>
# <tr><td> 2020-10 </td>
# <td> 287 </td>
# <td> 1089 </td>
# <td> 639 </td>
# <td> 43 </td>
# <td> 409 </td>
# <td> 1166 </td>
# </tr>
# <tr><td> 2020-12 </td>
# <td> 327 </td>
# <td> 1113 </td>
# <td> 768 </td>
# <td> 56 </td>
# <td> 409 </td>
# <td> 1315 </td>
# </tr>
# <tr><td> 2010-09 </td>
# <td> 0 </td>
# <td> 0 </td>
# <td> 0 </td>
# <td> 0 </td>
# <td> 0 </td>
# <td> 1 </td>
# </tr>
# <tr><td> 2019-01 </td>
# <td> 0 </td>
# <td> 0 </td>
# <td> 0 </td>
# <td> 0 </td>
# <td> 0 </td>
# <td> 1 </td>
# </tr>
# <tr><td> 2021-02 </td>
# <td> 288 </td>
# <td> 940 </td>
# <td> 697 </td>
# <td> 51 </td>
# <td> 357 </td>
# <td> 1181 </td>
# </tr>
# <tr><td> 2021-03 </td>
# <td> 251 </td>
# <td> 949 </td>
# <td> 644 </td>
# <td> 41 </td>
# <td> 270 </td>
# <td> 1101 </td>
# </tr>
# <tr><td> 2019-08 </td>
# <td> 0 </td>
# <td> 0 </td>
# <td> 0 </td>
# <td> 0 </td>
# <td> 0 </td>
# <td> 1 </td>
# </tr>
# <tr><td> 2015-04 </td>
# <td> 0 </td>
# <td> 0 </td>
# <td> 0 </td>
# <td> 0 </td>
# <td> 0 </td>
# <td> 1 </td>
# </tr>
# <tr><td> 2012-02 </td>
# <td> 0 </td>
# <td> 0 </td>
# <td> 0 </td>
# <td> 0 </td>
# <td> 0 </td>
# <td> 1 </td>
# </tr>
# <tr><td> 2016-03 </td>
# <td> 0 </td>
# <td> 0 </td>
# <td> 0 </td>
# <td> 0 </td>
# <td> 0 </td>
# <td> 1 </td>
# </tr>
# <tr><td> 2016-02 </td>
# <td> 0 </td>
# <td> 0 </td>
# <td> 0 </td>
# <td> 0 </td>
# <td> 0 </td>
# <td> 1 </td>
# </tr>
# <tr><td> 2017-12 </td>
# <td> 0 </td>
# <td> 0 </td>
# <td> 0 </td>
# <td> 0 </td>
# <td> 0 </td>
# <td> 1 </td>
# </tr>
# <tr><td> 2021-01 </td>
# <td> 347 </td>
# <td> 1112 </td>
# <td> 750 </td>
# <td> 44 </td>
# <td> 431 </td>
# <td> 1344 </td>
# </tr>
# <tr><td> 2021-06 </td>
# <td> 77 </td>
# <td> 211 </td>
# <td> 18 </td>
# <td> 0 </td>
# <td> 7 </td>
# <td> 895 </td>
# </tr>
# <tr><td> 2021-04 </td>
# <td> 225 </td>
# <td> 859 </td>
# <td> 418 </td>
# <td> 3 </td>
# <td> 232 </td>
# <td> 920 </td>
# </tr>
# <tr><td> 2021-05 </td>
# <td> 237 </td>
# <td> 889 </td>
# <td> 422 </td>
# <td> 0 </td>
# <td> 136 </td>
# <td> 1029 </td>
# </tr>
# </table>
# <br>
# <br>

# %%
import utils.dataReader as dataReader
import json
import pandas as pd
import datetime
import numpy as np

# %%
def ReadCSvAnddropDuplication (filePath, fileName,counties):

    countyName = ''
    countyCode = ''
    for key in counties:
        if fileName.find(counties[key]) != -1:
            countyName = counties[key] + ' County'
            countyCode = key

    rawDataBeforeFilingDateCheck = pd.read_csv(r'%s' %(filePath + fileName + '.csv'))
    rawData = checkFilingDate(rawDataBeforeFilingDateCheck)
    #create dict  {caseid:[{date: , name: }]}
    answerDict = {}
    answerTerm= {'answer'}
    serviceDict = {}
    serviceTerm= {'service'}
    dismissedDict = {}
    dismissedTerm= {'dismiss'}
    defaultJudgmentDict = {}
    defaultJudgmentTerm= {'default','dispossessory 4'}
    judgmentDict = {}
    judgmentTerm= {'writ','judgment'}

    for index, row in rawData.iterrows():

        if row['caseID'] not in answerDict:
            answerDict[row['caseID']] = []
            serviceDict[row['caseID']] = []
            dismissedDict[row['caseID']] = []
            defaultJudgmentDict[row['caseID']] = []
            judgmentDict[row['caseID']] = []

        if not pd.isna(row['eventName']):
            for term in answerTerm:
                if row['eventName'].lower().find(term) != -1:
                    answerDict[row['caseID']].append({'date': row['eventDate'],'name':row['eventName']})
                    break

            for term in serviceTerm:
                if row['eventName'].lower().find(term) != -1:
                    serviceDict[row['caseID']].append({'date': row['eventDate'],'name':row['eventName']})
                    break

            for term in dismissedTerm:
                if row['eventName'].lower().find(term) != -1:
                    dismissedDict[row['caseID']].append({'date': row['eventDate'],'name':row['eventName']})
                    break

            for term in defaultJudgmentTerm:
                if row['eventName'].lower().find(term) != -1:
                    defaultJudgmentDict[row['caseID']].append({'date': row['eventDate'],'name':row['eventName']})
                    break

            for term in judgmentTerm:
                if row['eventName'].lower().find(term) != -1:
                    judgmentDict[row['caseID']].append({'date': row['eventDate'],'name':row['eventName']})
                    break

    # catch the cases with answer 
    validAnswerDict = {key:answerDict[key] for key in answerDict if len(answerDict[key]) > 0}
    validServiceDict = {key:serviceDict[key] for key in serviceDict if len(serviceDict[key]) > 0}
    validdismissedDict = {key:dismissedDict[key] for key in dismissedDict if len(dismissedDict[key]) > 0}
    validdefaultJudgmentDict = {key:defaultJudgmentDict[key] for key in defaultJudgmentDict if len(defaultJudgmentDict[key]) > 0}
    validjudgmentDict = {key:judgmentDict[key] for key in judgmentDict if len(judgmentDict[key]) > 0}

    # print(validAnswerDict)
    rawDataIDAddressOnly = rawData.drop(['eventNumber','eventDate','eventName','eventDescription'], axis=1)
    # rawDataIDAddressOnly = rawData.drop(['caseStatus','eventNumber','eventDate','eventName'], axis=1)
    # rawDataIDAddressOnly.head()
    # drop the events to get unique record for each case 
    rawDataIDAddressOnlyUnique = rawDataIDAddressOnly.drop_duplicates(subset='caseID', keep="first").reset_index(drop=True)

    # print(rawDataIDAddressOnlyUnique.head(30))

    rawDataIDAddressOnlyUnique = sortCasesByDateThenMostRecentCase(rawDataIDAddressOnlyUnique,validAnswerDict,'answerDate','answer','answerEventName')
    rawDataIDAddressOnlyUnique = sortCasesByDateThenMostRecentCase(rawDataIDAddressOnlyUnique,validServiceDict,'serviceDate','services','serviceEventName')
    rawDataIDAddressOnlyUnique = sortCasesByDateThenMostRecentCase(rawDataIDAddressOnlyUnique,validdismissedDict,'dismissDate','dismiss','dismissEventName')
    rawDataIDAddressOnlyUnique = sortCasesByDateThenMostRecentCase(rawDataIDAddressOnlyUnique,validdefaultJudgmentDict,'defaultJudgmentDate','defaultjudgment','defaultJudgmentEventName')
    rawDataIDAddressOnlyUnique = sortCasesByDateThenMostRecentCase(rawDataIDAddressOnlyUnique,validjudgmentDict,'judgmentDate','judgment','judgmentEventName')

    # print('Number of cases in ' + countyName +' of 2020: ', rawDataIDAddressOnlyUnique.shape[0],' <br> ')

    rawDataIDAddressOnlyUnique['county'] = countyCode
    
    return rawDataIDAddressOnlyUnique
    #rawDataIDAddressOnlyUnique.head()

def sortCasesByDateThenMostRecentCase(rawDataIDAddressOnlyUnique,validAnswerDict,answerDate,ifAnswered,answerEventName):
    # sort each valid answer case by date
    for key in validAnswerDict:
        # for ele in validAnswerDict[key]:
        # 	#08/24/2020
        # 	if(len(ele['date'].split(' ')[0].split('/')[2]) > 2):
        # 		print(datetime.datetime.strptime(ele['date'].split(' ')[0],'%m/%d/%Y'))
        # 	else:
        # 		#8/24/20
        # 		print(datetime.datetime.strptime(ele['date'].split(' ')[0],'%m/%d/%y'))
        validAnswerDict[key].sort(key=lambda x: datetime.datetime.strptime(x['date'].split(' ')[0],'%m/%d/%Y')
         if (len(x['date'].split(' ')[0].split('/')[2]) > 2) 
         else datetime.datetime.strptime(x['date'].split(' ')[0],'%m/%d/%y'),reverse = False)

    #add answer info to the raw data
    rawDataIDAddressOnlyUnique[answerDate] = 'N/A'
    rawDataIDAddressOnlyUnique[ifAnswered] = '0'
    rawDataIDAddressOnlyUnique[answerEventName] = 'N/A'

    for index, row in rawDataIDAddressOnlyUnique.iterrows():

        if row['caseID'] in validAnswerDict:
            rawDataIDAddressOnlyUnique.at[index,answerDate] = validAnswerDict[row['caseID']][0]['date']
            rawDataIDAddressOnlyUnique.at[index,ifAnswered] = '1'
            rawDataIDAddressOnlyUnique.at[index,answerEventName] = validAnswerDict[row['caseID']][0]['name']

    return rawDataIDAddressOnlyUnique


def checkFilingDate(rawData):
    rawData['filingdate'] = rawData['fileDate'].map(lambda x: datetime.datetime.strptime(x, '%m/%d/%Y').date()
                                            if (len(x.split('/')[2]) > 2) 
                                             else datetime.datetime.strptime(x, '%m/%d/%y').date()

                                            )

    todayPlus7 = datetime.date.today() + datetime.timedelta(days=7)

    # replace the filedate by the eventDate of the first event or null if eventDate is unavailable if the filing Date is later than one week after today 
    timeRange = (rawData['filingdate'] > todayPlus7) & ((rawData['eventNumber'] == 1) | (pd.isna(rawData['eventNumber'])))
    rawDataAfterCheck = rawData.copy()
    rawDataAfterCheck['fileDate'] = np.where(timeRange,rawDataAfterCheck['eventDate'],rawDataAfterCheck['fileDate'])
#     rawDataAfterCheck = rawDataAfterCheck.drop(['fileDateFormatted'], axis=1)
    # return rawDataAfterCheck[rawDataAfterCheck['caseID'] == '21-M-05366']
    return rawDataAfterCheck

# %%
with open('./config.json') as configFile:
    config = json.load(configFile)
#define global variables
filePathForRawCaseData = config['filePathForRawCaseData']
filePathForPreRawCaseData = config['filePathForPreRawCaseData']
filePathForBackUpFolderOneLevelUp = config['filePathForBackUpFolderOneLevelUp']
counties = config['counties']
filePathForWorkFolder = config['filePathForWorkFolder']
filePathForWorkFolderRawData = config['filePathForWorkFolderRawData']
filePathForWorkFolderPreRawData = config['filePathForWorkFolderPreRawData']


fileNamePool,countyCodePool = dataReader.findRawData("./07262021/",counties)
#fileNamePool = ['2020ClaytonCountyEvictionCaseEvents-SCRAPE-09-25-2020','2020CobbCountyEvictionCaseEvents-SCRAPE-09-25-2020','2020DeKalbCountyEvictionCaseEvents-SCRAPE-09-25-2020','2020FultonCountyEvictionCaseEvents-SCRAPE-09-25-2020','2020GwinnettCountyEvictionCaseEvents-SCRAPE-09-25-2020'] 
#countyCodePool = ['063','067','089','121','135']

frames = []

for key, ele in enumerate(fileNamePool):

    countyName = ''
    for key2 in counties:
        if fileNamePool[key].find(counties[key2]) != -1:
            countyName = counties[key2] + ' County'

    rawDataIDAddressOnlyUnique = ReadCSvAnddropDuplication("./07262021/", fileNamePool[key],counties)
    
    
    
    frames.append(rawDataIDAddressOnlyUnique)

result = pd.concat(frames)

# %%
result["filingdate"] = result['filingdate'].apply(lambda x: x.strftime('%Y-%m-%d'))
# print(rawDataIDAddressOnlyUnique["filingdate"])

# %%
statsDict = {}
for index, case in result.iterrows():
#     print(case['filingdate'].split('-'))
    if case['county'] != '':
        if case['county'] in statsDict:
            if case['filingdate'].split('-')[0]+'-'+case['filingdate'].split('-')[1] in statsDict[case['county']]:
                statsDict[case['county']][case['filingdate'].split('-')[0]+'-'+case['filingdate'].split('-')[1]]['all'] += 1
                if case['services'] == '1':
                    statsDict[case['county']][case['filingdate'].split('-')[0]+'-'+case['filingdate'].split('-')[1]]['services'] += 1

                if case['dismiss'] == '1':
                    statsDict[case['county']][case['filingdate'].split('-')[0]+'-'+case['filingdate'].split('-')[1]]['dismiss'] += 1

                if case['answer'] == '1':
                    statsDict[case['county']][case['filingdate'].split('-')[0]+'-'+case['filingdate'].split('-')[1]]['answer'] += 1

                if case['defaultjudgment'] == '1':
                    statsDict[case['county']][case['filingdate'].split('-')[0]+'-'+case['filingdate'].split('-')[1]]['defaultjudgment'] += 1

                if case['judgment'] == '1':
                    statsDict[case['county']][case['filingdate'].split('-')[0]+'-'+case['filingdate'].split('-')[1]]['judgment'] += 1
            else:
                statsDict[case['county']][case['filingdate'].split('-')[0]+'-'+case['filingdate'].split('-')[1]] = {}
                
                if case['answer'] == '1':
                    statsDict[case['county']][case['filingdate'].split('-')[0]+'-'+case['filingdate'].split('-')[1]]['answer'] = 1
                else:
                    statsDict[case['county']][case['filingdate'].split('-')[0]+'-'+case['filingdate'].split('-')[1]]['answer'] = 0

                if case['services'] == '1':
                    statsDict[case['county']][case['filingdate'].split('-')[0]+'-'+case['filingdate'].split('-')[1]]['services'] = 1
                else:
                    statsDict[case['county']][case['filingdate'].split('-')[0]+'-'+case['filingdate'].split('-')[1]]['services'] = 0

                if case['dismiss'] == '1':
                    statsDict[case['county']][case['filingdate'].split('-')[0]+'-'+case['filingdate'].split('-')[1]]['dismiss'] = 1
                else:
                    statsDict[case['county']][case['filingdate'].split('-')[0]+'-'+case['filingdate'].split('-')[1]]['dismiss'] = 0

                

                if case['defaultjudgment'] == '1':
                    statsDict[case['county']][case['filingdate'].split('-')[0]+'-'+case['filingdate'].split('-')[1]]['defaultjudgment'] = 1
                else:
                    statsDict[case['county']][case['filingdate'].split('-')[0]+'-'+case['filingdate'].split('-')[1]]['defaultjudgment'] = 0

                if case['judgment'] == '1':
                    statsDict[case['county']][case['filingdate'].split('-')[0]+'-'+case['filingdate'].split('-')[1]]['judgment'] = 1
                else:
                    statsDict[case['county']][case['filingdate'].split('-')[0]+'-'+case['filingdate'].split('-')[1]]['judgment'] = 0
                    
                statsDict[case['county']][case['filingdate'].split('-')[0]+'-'+case['filingdate'].split('-')[1]]['all'] = 1
        else:
            statsDict[case['county']]={}
            
            statsDict[case['county']][case['filingdate'].split('-')[0]+'-'+case['filingdate'].split('-')[1]] = {}
            
            if case['answer'] == '1':
                statsDict[case['county']][case['filingdate'].split('-')[0]+'-'+case['filingdate'].split('-')[1]]['answer'] = 1
            else:
                statsDict[case['county']][case['filingdate'].split('-')[0]+'-'+case['filingdate'].split('-')[1]]['answer'] = 0
                
            if case['services'] == '1':
                statsDict[case['county']][case['filingdate'].split('-')[0]+'-'+case['filingdate'].split('-')[1]]['services'] = 1
            else:
                statsDict[case['county']][case['filingdate'].split('-')[0]+'-'+case['filingdate'].split('-')[1]]['services'] = 0

            if case['dismiss'] == '1':
                statsDict[case['county']][case['filingdate'].split('-')[0]+'-'+case['filingdate'].split('-')[1]]['dismiss'] = 1
            else:
                statsDict[case['county']][case['filingdate'].split('-')[0]+'-'+case['filingdate'].split('-')[1]]['dismiss'] = 0

            if case['defaultjudgment'] == '1':
                statsDict[case['county']][case['filingdate'].split('-')[0]+'-'+case['filingdate'].split('-')[1]]['defaultjudgment'] = 1
            else:
                statsDict[case['county']][case['filingdate'].split('-')[0]+'-'+case['filingdate'].split('-')[1]]['defaultjudgment'] = 0

            if case['judgment'] == '1':
                statsDict[case['county']][case['filingdate'].split('-')[0]+'-'+case['filingdate'].split('-')[1]]['judgment'] = 1
            else:
                statsDict[case['county']][case['filingdate'].split('-')[0]+'-'+case['filingdate'].split('-')[1]]['judgment'] = 0
                
            statsDict[case['county']][case['filingdate'].split('-')[0]+'-'+case['filingdate'].split('-')[1]]['all'] = 1

# %%
print(statsDict)
# Out:
# {'135': {'2020-01': {'answer': 564, 'services': 2189, 'dismiss': 1455, 'defaultjudgment': 113, 'judgment': 1299, 'all': 2473}, '2020-09': {'answer': 311, 'services': 1092, 'dismiss': 540, 'defaultjudgment': 46, 'judgment': 389, 'all': 1141}, '2020-02': {'answer': 452, 'services': 2088, 'dismiss': 1495, 'defaultjudgment': 97, 'judgment': 962, 'all': 2291}, '2020-11': {'answer': 306, 'services': 1070, 'dismiss': 745, 'defaultjudgment': 40, 'judgment': 386, 'all': 1290}, '2020-03': {'answer': 150, 'services': 1264, 'dismiss': 1047, 'defaultjudgment': 16, 'judgment': 108, 'all': 1517}, '2020-04': {'answer': 29, 'services': 126, 'dismiss': 70, 'defaultjudgment': 6, 'judgment': 20, 'all': 146}, '2020-05': {'answer': 28, 'services': 128, 'dismiss': 53, 'defaultjudgment': 10, 'judgment': 37, 'all': 147}, '2020-06': {'answer': 49, 'services': 167, 'dismiss': 82, 'defaultjudgment': 11, 'judgment': 67, 'all': 194}, '2020-07': {'answer': 75, 'services': 256, 'dismiss': 144, 'defaultjudgment': 17
# ...

# %%
counties= {
    "063":"Clayton",
    "067":"Cobb",
    "089":"DeKalb",
    "121":"Fulton",
    "135":"Gwinnett"
}
for key in counties:

    titleLine = '<tr><td>Filing Month/Year</td>'
    totalCountLine = '<tr><td></td>'
    titleLine = titleLine + '<td colspan="6">'+ counties[key] + '</td>'
# <td> 1952 </td>
# <td> 2086 </td>
# <td> 3021 </td>
# <td> 4153 </td>
# <td> 2113 </td>
# <td> 1013 </td>
# <td> 643 </td>
# <td> 480 </td>
# </tr>
# <tr><td> 10-2020 </td>
# <td> 1020 </td>
# <td> 958 </td>
# <td> 1723 </td>
# <td> 1841 </td>
# <td> 1163 </td>
# <td> 559 </td>
# <td> 359 </td>
# <td> 384 </td>
# </tr>
# <tr><td> 11-2019 </td>
# <td> 1725 </td>
# <td> 1795 </td>
# <td> 2903 </td>
# <td> 3602 </td>
# <td> 2134 </td>
# <td> 814 </td>
# <td> 595 </td>
# <td> 416 </td>
# </tr>
# <tr><td> 11-2020 </td>
# <td> 1220 </td>
# <td> 1094 </td>
# <td> 1583 </td>
# <td> 2330 </td>
# <td> 1290 </td>
# <td> 617 </td>
# <td> 352 </td>
# <td> 337 </td>
# </tr>
# <tr><td> 12-2019 </td>
# <td> 1876 </td>
# <td> 1619 </td>
# <td> 2998 </td>
# <td> 3847 </td>
# <td> 2270 </td>
# <td> 886 </td>
# <td> 641 </td>
# <td> 461 </td>
# </tr>
# <tr><td> 12-2020 </td>
# <td> 1204 </td>
# <td> 1171 </td>
# <td> 1772 </td>
# <td> 2330 </td>
# <td> 1309 </td>
# <td> 634 </td>
# <td> 253 </td>
# <td> 308 </td>
# </tr>
# </table>
# <br>
# <br>

# %%
df = pd.read_csv('./test/2019MaconbibbCountyEvictionCaseEvents-SCRAPE-09-10-2021.csv')
df["defendantName2"] = df["defendantName1"]
df["defendantAddress2"] = df["defendantAddress1"]
df["defendantCity2"] = df["defendantCity1"]
df["defendantPhone2"] = df["defendantPhone1"]
df["defendantAttorney2"] = df["defendantAttorney1"]

df["defendantName1"] = df["defendantName0"]
df["defendantAddress1"] = df["defendantAddress0"]
df["defendantCity1"] = df["defendantCity0"]
df["defendantPhone1"] = df["defendantPhone0"]
df["defendantAttorney1"] = df["defendantAttorney0"]

df = df.drop(['defendantName0','defendantAddress0','defendantCity0','defendantPhone0','defendantAttorney0'], axis=1)
display(df)
df.to_csv('2019MaconbibbCountyEvictionCaseEvents-SCRAPE-09-10-2021.csv',index=False)
# Out:
#          fileDate     caseID                       plaintiff  \
# 0      01/03/2019  19036422s                    Scott, Bryan
# 1      01/03/2019  19036424S   KING MANAGEMENT SOLUTIONS LLC
# 2      01/03/2019  19036423s         JOHNSON, LINDA CAMPBELL
# 3      01/03/2019  19036424S   KING MANAGEMENT SOLUTIONS LLC
# 4      01/03/2019  19036424S   KING MANAGEMENT SOLUTIONS LLC
# ...           ...        ...                             ...
# 29610  09/10/2021  21065872S  REAL PROPERTY MANAGEMENT VESTA
# 29611  09/10/2021  21065874S   SAI REAL ESTATE HOLDINGS, LLC
# 29612  09/10/2021  21065875S   SAI REAL ESTATE HOLDINGS, LLC
# 29613  09/10/2021  21065878S               MADISON STAR, LLC
# 29614  09/10/2021  21065879S                  SODOGAR, SONNY
#
#                 plaintiffAddress plaintiffCity  plaintiffPhone  \
# 0               635 Pio Nono Ave      MACON,GA             NaN
